# %%
num=float(input("enter the value"))
int_num=int(num)
print(f"the intergales parts if number is {int_num}")
float_parts=num-int_num
print(f"the float part is {float_parts}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 num=float(input("enter the value"))
#       2 int_num=int(num)
#       3 print(f"the intergales parts if number is {int_num}")
#
# ValueError: could not convert string to float: ''
